# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
file_path = 'HistoricalData_1655174160675.csv'
df = pd.read_csv(file_path)
df.head(10)
# Out:
#          Date Close/Last   Volume     Open       High        Low
# 0  06/13/2022    $283.16  4704607  $284.36    $286.82  $281.2801
# 1  06/10/2022    $289.24  4625619   $291.5     $296.5    $288.64
# 2  06/09/2022    $299.86  4170367  $297.76    $306.88    $297.35
# 3  06/08/2022    $297.53  3003115  $299.78    $300.58  $295.6823
# 4  06/07/2022    $301.77  3547797  $295.06    $302.38     $292.6
# 5  06/06/2022    $303.89  2562003  $305.56   $307.613    $303.25
# 6  06/03/2022    $305.08  2956559  $303.33    $308.46     $301.9
# 7  06/02/2022    $305.87  4086408  $298.81    $306.03  $295.8933
# 8  06/01/2022    $297.19  3080760  $301.74    $302.98    $297.03
# 9  05/31/2022    $302.75  5966574   $306.6  $307.8659    $300.83

# %%
import pandas as pd
import numpy as np
def correlation ( attribute1 , fileName1 , attribute2, fileName2 ):
    '''
    Input Parameters:
        attribute1: The attribute you want to consider from file1
        attribute2: The attribute you want to consider from file2
        fileName1: The comma seperated file1 with the different format first line removed
        fileName2: The comma seperated file2 with the different format first line removed
        
    Output:
        Return the correlation coefficient
        Do not return a string
        Do not write anything to stdout
        Points will be deducted if these instructions are not followed strictly

    '''
    #TODO: Write code given the Input / Output Paramters.
    csv_file1 = pd.read_csv(fileName1)
    pd_attribute1 = csv_file1[attribute1]
    pd_attribute1= pd_attribute1.str.replace('$', '')
    pd_attribute1= pd_attribute1.astype(float)
    csv_file2 = pd.read_csv(fileName2)
    pd_attribute2 = csv_file2[attribute2]
    pd_attribute2= pd_attribute2.str.replace('$', '')
    pd_attribute2= pd_attribute2.astype(float)
    print(pd_attribute2)
    corr= np.corrcoef(pd_attribute1, pd_attribute2)
    return corr

# %%
correlation( 'Open', 'HistoricalData_1655174160675.csv', 'Low', 'HistoricalData_1655174160675.csv')
# Out:
# 0      281.2801
# 1      288.6400
# 2      297.3500
# 3      295.6823
# 4      292.6000
#          ...
# 248    298.4000
# 249    300.0300
# 250    301.1700
# 251    303.4850
# 252    306.2200
# Name: Low, Length: 253, dtype: float64
# /var/folders/x0/w6k04t5d56dccwy_7nbrnn5w0000gn/T/ipykernel_53936/868552959.py:21: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   pd_attribute1= pd_attribute1.str.replace('$', '')
# /var/folders/x0/w6k04t5d56dccwy_7nbrnn5w0000gn/T/ipykernel_53936/868552959.py:25: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   pd_attribute2= pd_attribute2.str.replace('$', '')
# array([[1.        , 0.99543157],
#        [0.99543157, 1.        ]])

# %%
import pandas as pd
import numpy as np
def min_max_normalization(fileName, attribute):
    '''
    Input Parameters:
        fileName: The comma seperated file that must be considered for the normalization with the different format first line removed
        attribute: The attribute for which you are performing the normalization
        
    Output:
        Return an object of list type of normalized values
        Please do not return a list of strings
        Please do not print anything to stdout
        Use only Python3
        Points will be deducted if you do not follow exact instructions
    '''
    csv_file = pd.read_csv(fileName)
    pd_attribute = csv_file[attribute]
    pd_attribute= pd_attribute.str.replace('$', ' ')
    pd_attribute= pd_attribute.astype(float)
    # TODO: Write code given the Input / Output Paramters.
    min_value = min(pd_attribute)
    max_value = max(pd_attribute)
    dif = max_value - min_value
    mmn = []
    for d in pd_attribute:
        normalized = (d - min_value) / dif
        mmn.append([d, normalized])
    return mmn

# %%
min_max_normalization ( 'HistoricalData_1655174160675.csv','Open')
# Out:
# /var/folders/x0/w6k04t5d56dccwy_7nbrnn5w0000gn/T/ipykernel_53936/2696844087.py:18: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   pd_attribute= pd_attribute.str.replace('$', ' ')
# [[284.36, 0.020601048512146645],
#  [291.5, 0.07332201137118811],
#  [297.76, 0.11954515247729453],
#  [299.78, 0.13446060695562267],
#  [295.06, 0.09960865391715283],
#  [305.56, 0.1771394816510375],
#  [303.33, 0.1606734106180314],
#  [298.81, 0.12729823525068307],
#  [301.74, 0.14893302813261475],
#  [306.6, 0.18481872554087003],
#  [303.54, 0.16222402717270934],
#  [297.32, 0.116296241600827],
#  [285.81, 0.031307686627778254],
#  [284.0, 0.017942848704127642],
#  [289.09, 0.0555268404341725],
#  [289.82, 0.060917078933766515],
#  [285.5, 0.02901868123753974],
#  [293.0, 0.08439784390460021],
#  [306.5, 0.18408033670530904],
# ...

# %%
def z_score(data_list):
    mean = numpy.mean(data_list)
    std_deviation = numpy.std(data_list)
    result = []
    for data in data_list:
        # z_score formula is as follows: (x - mean) / standard_deviation
        normalized = (data - mean) / std_deviation
        # append original value and new value as a list
        result.append([data, normalized])
    return result

# %%
def zscore_normalization(fileName, attribute):
    '''
    Input Parameters:
        fileName: The comma seperated file that must be considered for the normalization with the different format first line removed
        attribute: The attribute for which you are performing the normalization
        
    Output:
        Return an object of list type of normalized values
        Please do not return a list of strings
        Please do not print anything to stdout
        Use only Python3
        Points will be deducted if you do not follow exact instructions
    '''
    csv_file = pd.read_csv(fileName)
    pd_attribute = csv_file[attribute]
    pd_attribute= pd_attribute.str.replace('$', ' ')
    pd_attribute= pd_attribute.astype(float)
    mean = np.mean(pd_attribute)
    std_deviation = np.std(pd_attribute)
    z = []
    for d in pd_attribute:
        normalized = (d - mean) / std_deviation
        z.append([d, normalized])
    return z

# %%
zscore_normalization ( 'HistoricalData_1655174160675.csv','Open')
# Out:
# /var/folders/x0/w6k04t5d56dccwy_7nbrnn5w0000gn/T/ipykernel_53936/3585797355.py:16: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   pd_attribute= pd_attribute.str.replace('$', ' ')
# [[284.36, -1.5591978891501679],
#  [291.5, -1.357480553274774],
#  [297.76, -1.1806247377873835],
#  [299.78, -1.1235562478058299],
#  [295.06, -1.256904402614213],
#  [305.56, -0.960261261620986],
#  [303.33, -1.0232626144224053],
#  [298.81, -1.1509604236880606],
#  [301.74, -1.0681828614870932],
#  [306.6, -0.9308794647987991],
#  [303.54, -1.0173297516025397],
#  [297.32, -1.1930554979813854],
#  [285.81, -1.5182328839653894],
#  [284.0, -1.569368511127079],
#  [289.09, -1.4255672170646487],
#  [289.82, -1.4049434558336904],
#  [285.5, -1.526990919556618],
#  [293.0, -1.3151029617043128],
#  [306.5, -0.9337046375701639],
# ...

# %%
csv_file = pd.read_csv('HistoricalData_1655174160675.csv')
pd_attribute1 = csv_file['High']
pd_attribute2 = csv_file['Low']
pd_attribute1= pd_attribute1.str.replace('$', ' ')
pd_attribute1= pd_attribute1.astype(float)
pd_attribute2= pd_attribute2.str.replace('$', ' ')
pd_attribute2= pd_attribute2.astype(float)
# Out:
# /var/folders/x0/w6k04t5d56dccwy_7nbrnn5w0000gn/T/ipykernel_53936/4273171761.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   pd_attribute1= pd_attribute1.str.replace('$', ' ')
# /var/folders/x0/w6k04t5d56dccwy_7nbrnn5w0000gn/T/ipykernel_53936/4273171761.py:6: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   pd_attribute2= pd_attribute2.str.replace('$', ' ')

# %%
plt.figure(figsize=(16,10))
plt.plot(pd_attribute1, c='r')
plt.plot(pd_attribute2, c='b')
plt.xlabel("red Open, blue Low")
plt.show()

# %%
pd_attribute1 = csv_file['Open']
pd_attribute2 = csv_file['Close/Last']
pd_attribute1= pd_attribute1.str.replace('$', ' ')
pd_attribute1= pd_attribute1.astype(float)
pd_attribute2= pd_attribute2.str.replace('$', ' ')
pd_attribute2= pd_attribute2.astype(float)
# Out:
# /var/folders/x0/w6k04t5d56dccwy_7nbrnn5w0000gn/T/ipykernel_53936/179590454.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   pd_attribute1= pd_attribute1.str.replace('$', ' ')
# /var/folders/x0/w6k04t5d56dccwy_7nbrnn5w0000gn/T/ipykernel_53936/179590454.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   pd_attribute2= pd_attribute2.str.replace('$', ' ')

# %%
plt.boxplot(pd_attribute1)
plt.xlabel("Open")

# show plot
plt.show()

# %%
plt.boxplot(pd_attribute2)
plt.xlabel("Close/Last")

# show plot
plt.show()

# %%
pd_attribute1 = csv_file['Volume']

# %%
plt.hist(pd_attribute1, edgecolor="r", bins=10)
plt.xlabel("Volume")
plt.show()

# %%
plt.boxplot(pd_attribute1)
plt.xlabel("Volume")

# show plot
plt.show()
